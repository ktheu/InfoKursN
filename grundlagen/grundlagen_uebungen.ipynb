# %% [markdown]
# ### Grundlagen - Übungen

# %% [markdown]
# #### Aufgabe A1
# ```
# Setze p auf 6.
# Setze q auf 9.
# Erhöhe p um 3.
# Erniedrige q um 4.
# Gib in der ersten Zeile die Summe von p und q aus.
# Gib in der nächsten Zeile das Produkt von p und q aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 14
# 45
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A2
# ```
# Setze c auf 8 und d auf 15.
# Erhöhe d um das Doppelte von c.
# Erhöhe den Wert von c um 2 und gib dann die Summe von c und d aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 41
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A3
# ```
# Setze m auf 3, n auf m plus 5, k auf 2 minus n.
# Gib m, n und k in einer Zeile aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 3 8 -6
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A4
# ```
# Setze a auf 15.
# Setze b auf 5.
# c ist a dividiert durch b.
# d ist a ganzzahlig dividiert durch b.
# Gib c aus.
# Gib d aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 3.0
# 3
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A5
#
# Gegeben sind die folgenden Ausdrücke:
#
# - $5 + 3 \cdot x$
# - $\frac{10 - 2 \cdot x}{3}$
# - $4 \cdot x^2 - 7$
#
# Weise die oben stehenden Ausdrücke den Variablen a, b, c zu.
# Gib in der ersten Zeile die Werte von a, b, c aus, wenn x = 2.
# Gib in der nächsten Zeile die Werte von a, b, c aus, wenn x = -3.
#
# **Erwartete Ausgabe:**
# ```
# 11 2.0 9
# -4 5.333333333333333 29
# ```
# (Hinweis: Python gibt bei einer Division immer die volle Nachkommagenauigkeit aus, daher die vielen Nachkommastellen bei b.)

# %%
# your code

# %% [markdown]
# #### Aufgabe A6
#
# Nutze in den Stern-Zeilen (\*) die Kurzform für die Zuweisungen.
# ```
# Setze c auf 3.
# Setze d auf 6.
# Verdreifache c.      (*)
# Erhöhe d um 4.       (*)
# Erhöhe c um d.       (*)
# Teile c ganzzahlig durch 2.     (*)
# Gib c und d aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 9 10
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A7
# ```
# Setze radius auf 4.5.
# Setze pi auf 3.1415.
# Berechne die Fläche des Kreises und speichere sie in einer Variablen namens flaeche.
# ```
# **Erwartete Ausgabe:**
# ```
# 63.615375
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A8
#
# Kommentiere alle Zuweisungen aus, die Variablennamen verwenden, die nicht unserer
# Vereinbarung entsprechen. Ergänze bei jeder auskommentierten Zeile einen kurzen Kommentar, warum sie gegen die Konvention verstößt.

# %%
Gewicht = 12
laengedesweges = 20
wärmegrad = 15
straße_breite = 3
anzahlSchritte = 8
punkte_pro_runde = 3
zeitInSekunden = 42

# %% [markdown]
# #### Aufgabe A9
# ```
# Setze a auf 29.
# Setze b auf 4.
# q ist das Ergebnis der ganzzahligen Division (//) von a durch b.
# r ist der Rest der Division (Modulo, %) von a durch b.
# Gib q und r in einer Zeile aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 7 1
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A10
# ```
# Erstelle drei Variablen a, b, c mit den Inhalten 'Der', 'Himmel', 'ist blau'.
# Erstelle durch Aneinanderpappen (mit Leerzeichen dazwischen) eine Variable satz
# mit dem Inhalt 'Der Himmel ist blau.' (Punkt nicht vergessen!)
# Gib satz aus.
# Gib zusätzlich die Länge von satz aus.
# ```
# **Erwartete Ausgabe:**
# ```
# Der Himmel ist blau.
# 20
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A11
#
# Gegeben ist der String `s = 'Wasserfall'`.
# ```
# Weise der Variablen c1 mit einem positiven Index das Zeichen 'e' zu.
# Weise der Variablen c2 mit einem negativen Index dasselbe Zeichen 'e' zu.
# Weise der Variablen c3 mit einem negativen Index das letzte Zeichen des Strings zu.
# Gib c1, c2 und c3 in einer Zeile aus.
# ```
# **Erwartete Ausgabe:**
# ```
# e e l
# ```

# %%
s = 'Wasserfall'
# your code

# %% [markdown]
# #### Aufgabe A12
#
# Schreibe ein Python-Programm, das zwei ganze Zahlen über `input()` einliest
# und deren Summe und Produkt mit f-Strings ausgibt.
#
# Beispieldialog: (Eingaben sind mit `>>>` markiert.)
# ```
# >>> Zahl1: 8
# >>> Zahl2: 6
# Die Summe von 8 und 6 ist 14.
# Das Produkt von 8 und 6 ist 48.
# ```

# %%
# your code
