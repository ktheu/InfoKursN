# %% [markdown]
# ### Bedingungen - Übungen

# %% [markdown]
# #### Aufgabe A1
# ```
# Lies eine ganze Zahl alter ein.
# Setze die Variable eintritt auf 'erlaubt', falls alter mindestens 18 ist,
# sonst auf 'nicht erlaubt'.
# Gib eintritt aus.
# ```
# **Beispieldialog:**
# ```
# Alter: 16
# nicht erlaubt
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A2
# ```
# Lies eine ganze Zahl t (Temperatur in Grad) ein.
# Gib aus:
# 'heiß', wenn t größer als 30 ist,
# 'mild', wenn t zwischen 15 und 30 liegt (einschließlich),
# 'kalt', wenn t kleiner als 15 ist.
# ```
# **Beispieldialog:**
# ```
# Temperatur: 22
# mild
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A3
#
# Der Ausdruck ist: `(A or B) and not A`
#
# Überlege dir zuerst im Kopf, was er für die folgenden drei Kombinationen ergibt.
# Setze dann A und B nacheinander auf die jeweiligen Werte, speichere das Ergebnis
# in b1, b2 bzw. b3 und gib am Ende alle drei aus, um deine Überlegung zu prüfen.
# ```
# 1) A = False, B = True   -> b1
# 2) A = True,  B = True   -> b2
# 3) A = False, B = False  -> b3
# ```
# **Erwartete Ausgabe:**
# ```
# True
# False
# False
# ```

# %%
# Vermutung: b1=..., b2=..., b3=...

# your code

# %% [markdown]
# #### Aufgabe A4
#
# Der Ausdruck ist: `(A and not B) or C`
#
# Überlege dir zuerst im Kopf, was er für die folgenden vier Kombinationen ergibt.
# Setze dann A, B und C nacheinander auf die jeweiligen Werte, speichere das Ergebnis
# in b1, b2, b3 bzw. b4 und gib am Ende alle vier aus, um deine Überlegung zu prüfen.
# ```
# 1) A = True,  B = False, C = False  -> b1
# 2) A = False, B = False, C = False  -> b2
# 3) A = False, B = True,  C = True   -> b3
# 4) A = True,  B = True,  C = False  -> b4
# ```
# **Erwartete Ausgabe:**
# ```
# True
# False
# True
# False
# ```

# %%
# Vermutung: b1=..., b2=..., b3=..., b4=...

# your code

# %% [markdown]
# #### Aufgabe A5
# ```
# Schreibe einen Ausdruck ausdruck, der wahr ist, wenn x größer als 20
# und durch 3 teilbar ist.
# Teste ihn mit x = 21 und gib ausdruck aus.
# Teste ihn danach mit x = 25 und gib ausdruck erneut aus.
# ```
# **Erwartete Ausgabe:**
# ```
# True
# False
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A6
# ```
# Schreibe einen Ausdruck ausdruck2, der wahr ist, wenn y zwischen 50 und 60
# (einschließlich beider Grenzen) liegt oder wenn y durch 9 teilbar ist.
# Teste ihn mit y = 55, dann mit y = 63, dann mit y = 40
# und gib ausdruck2 jedes Mal aus.
# ```
# **Erwartete Ausgabe:**
# ```
# True
# True
# False
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A7
# ```
# Schreibe mit einer while-Schleife ein Programm, das die Zahlen
# von 8 bis 15 ausgibt.
# ```
# **Erwartete Ausgabe:**
# ```
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A8
#
# Was wird ausgegeben? Notiere zuerst deine Vermutung als Kommentar, dann führe die Zelle aus und vergleiche.
# ```
# x = 25
# print(x)
# while x >= 15:
#     x -= 4
#     print(x)
# ```

# %%
# Vermutung:


x = 25
print(x)
while x >= 15:
    x -= 4
    print(x)

# %% [markdown]
# #### Aufgabe A9
# ```
# Schreibe mit einer for-Schleife ein Programm, das die Zahlen
# von 4 bis 11 ausgibt.
# ```
# **Erwartete Ausgabe:**
# ```
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A10
# ```
# Schreibe mit einer for-Schleife ein Programm, das die Zahlen
# von 14 bis 9 ausgibt (absteigend).
# ```
# **Erwartete Ausgabe:**
# ```
# 14
# 13
# 12
# 11
# 10
# 9
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A11
#
# Was wird ausgegeben?
# ```
# i = 3
# for k in range(i):
#     print(i + k)
# ```

# %%
# Vermutung:


i = 3
for k in range(i):
    print(i + k)

# %% [markdown]
# #### Aufgabe A12
#
# Was wird ausgegeben?
# ```
# i = 7
# for k in range(4):
#     print(i)
# ```

# %%
# Vermutung:


i = 7
for k in range(4):
    print(i)

# %% [markdown]
# #### Aufgabe A13
# ```
# Schreibe ein Programm, das mit einer for-Schleife die Zahlen von 1 bis 40 durchläuft.
# Überspringe dabei alle Zahlen, die durch 4 teilbar sind (mit continue).
# Breche die Schleife ab (mit break), sobald eine Zahl größer als 25 ist.
# Gib alle nicht übersprungenen Zahlen aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 1
# 2
# 3
# 5
# 6
# 7
# 9
# 10
# 11
# 13
# 14
# 15
# 17
# 18
# 19
# 21
# 22
# 23
# 25
# ```

# %%
# your code
