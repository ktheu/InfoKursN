# %% [markdown]
# ### Datentypen, Listen, Zufall, Funktionen, Dateien - Übungen

# %% [markdown]
# #### Aufgabe A1
# ```
# Gegeben sind folgende Variablenzuweisungen:
# a = 12
# b = 4.75
# c = "Servus"
# d = False
#
# Gib für jede Variable mit type() den Datentyp aus.
# ```
# **Erwartete Ausgabe:**
# ```
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# ```

# %%
a = 12
b = 4.75
c = "Servus"
d = False

# your code

# %% [markdown]
# #### Aufgabe A2
# ```
# Gegeben ist der String s = '17'.
# Wandle s in eine Ganzzahl um, erhöhe sie um 5
# und gib das Ergebnis wieder als Zeichenkette aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 22
# ```

# %%
s = '17'
# your code

# %% [markdown]
# #### Aufgabe A3
# ```
# Erstelle eine leere Liste a.
# Füge nacheinander die Zahlen 9, 4, 21 ein.
# Gib die Liste aus.
# Gib die Länge von a aus.
# ```
# **Erwartete Ausgabe:**
# ```
# [9, 4, 21]
# 3
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A4
# ```
# Gegeben ist die Liste b = [3, 8, 15, 6, 21, 11].
#
# a) Weise das dritte Element auf zwei verschiedene Arten den Variablen
#    x1 und x2 zu (einmal mit positivem, einmal mit negativem Index).
# b) Weise das letzte Element auf drei verschiedene Arten den Variablen
#    y1, y2 und y3 zu.
#
# Gib x1, x2, y1, y2, y3 in einer Zeile aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 15 15 11 11 11
# ```

# %%
b = [3, 8, 15, 6, 21, 11]
# your code

# %% [markdown]
# #### Aufgabe A5
# ```
# Gegeben ist die Liste a = [3, 8, 5, 6, 4, 20].
# Verändere sie mit Python-Anweisungen so, dass sie am Ende
# wie folgt aussieht: [6, 8, 10, 6, 4, 20, 1, 7]
# (Tipp: zwei Werte werden verdoppelt, zwei neue Werte kommen hinzu.)
# Gib a aus.
# ```
# **Erwartete Ausgabe:**
# ```
# [6, 8, 10, 6, 4, 20, 1, 7]
# ```

# %%
a = [3, 8, 5, 6, 4, 20]
# your code

# %% [markdown]
# #### Aufgabe A6
# ```
# Gegeben ist die Liste woche = ['Mo', 'Di', 'Mi', 'Do', 'Fr'].
#
# Schreibe zwei Schleifen, die die Liste jeweils komplett ausgeben:
# 1) mit einer Laufvariablen über den Index (range(len(...)))
# 2) mit einer Laufvariablen direkt über die Elemente
#
# Beide Varianten sollen die gleiche Ausgabe erzeugen (also insgesamt
# zweimal Mo, Di, Mi, Do, Fr).
# Schreibe anschließend als Kommentar in die Zelle, worin sich die
# beiden Varianten unterscheiden.
# ```
# **Erwartete Ausgabe:**
# ```
# Mo
# Di
# Mi
# Do
# Fr
# Mo
# Di
# Mi
# Do
# Fr
# ```

# %%
woche = ['Mo', 'Di', 'Mi', 'Do', 'Fr']
# your code

# Unterschied:

# %% [markdown]
# #### Aufgabe A7
# ```
# Schreibe ein Programm, das mit einer Laufvariablen über den Index
# jedes Element der Liste zahlen verdoppelt (die Liste soll anschließend
# die verdoppelten Werte enthalten).
# zahlen = [3, 5, 9, 2]
# ```
# **Erwartete Ausgabe:**
# ```
# [6, 10, 18, 4]
# ```

# %%
zahlen = [3, 5, 9, 2]
# your code
print(zahlen)

# %% [markdown]
# #### Aufgabe A8
#
# Was gibt der folgende Code aus? Notiere zuerst deine Vermutung als Kommentar, dann führe die Zelle aus.
# ```
# a = [3, 7, 2, 10, 4]
# b = []
# teilsumme = 0
# for x in a:
#     teilsumme += x
#     b.append(teilsumme)
# print(b)
# ```

# %%
# Vermutung:


a = [3, 7, 2, 10, 4]
b = []
teilsumme = 0
for x in a:
    teilsumme += x
    b.append(teilsumme)
print(b)

# %% [markdown]
# #### Aufgabe A9
#
# Welchen Wert hat die Variable index nach Ausführung des folgenden Codes? Notiere zuerst deine Vermutung, dann führe die Zelle aus und prüfe.
# ```
# a = [4, 9, 2, 11, 6, 3]
# index = -1
# for i in range(len(a)):
#     if a[i] > 8 and index == -1:
#         index = i
# print(index)
# ```

# %%
# Vermutung:


a = [4, 9, 2, 11, 6, 3]
index = -1
for i in range(len(a)):
    if a[i] > 8 and index == -1:
        index = i
print(index)

# %% [markdown]
# #### Aufgabe A10
# ```
# Der folgende Code berechnet die Summe aller Zahlen einer Liste.
# Ergänze ihn so, dass zusätzlich gezählt wird, wie viele negative
# Zahlen in der Liste vorkommen, und gib diese Anzahl zusätzlich aus.
#
# a = [12, -5, 7, -3, 9, -8]
# summe = 0
# for x in a:
#     summe += x
# print(summe)
# ```
# **Erwartete Ausgabe:**
# ```
# 12
# 3
# ```

# %%
a = [12, -5, 7, -3, 9, -8]
summe = 0
# your code
print(summe)

# %% [markdown]
# #### Aufgabe A11
# ```
# Schreibe ein Programm, das mit dem Modul random eine ganze Zufallszahl
# zwischen 1 und 6 erzeugt und ausgibt (Simulation eines Würfelwurfs).
# ```
# **Hinweis:** Die Ausgabe ist zufällig — prüfe nur, dass eine Zahl
# zwischen 1 und 6 erscheint.

# %%
# your code

# %% [markdown]
# #### Aufgabe A12
# ```
# Schreibe ein Programm, das 5-mal hintereinander eine Zufallszahl
# zwischen 1 und 100 erzeugt und alle fünf Zahlen ausgibt.
# ```
# **Hinweis:** Die Ausgabe ist zufällig — prüfe nur, dass alle fünf
# Zahlen zwischen 1 und 100 liegen.

# %%
# your code

# %% [markdown]
# #### Aufgabe A13
#
# Führe die folgende Zelle zweimal hintereinander aus. Was fällt auf? Notiere deine Beobachtung als Kommentar.

# %%
import random
random.seed(7)
for i in range(3):
    print(random.random())

# Beobachtung:

# %% [markdown]
# Führe jetzt die folgende Zelle (ohne seed) zweimal hintereinander aus. Was ist diesmal anders? Notiere auch das als Kommentar.

# %%
import random
for i in range(3):
    print(random.random())

# Beobachtung:

# %% [markdown]
# #### Aufgabe A14
# ```
# Gegeben ist die folgende Python-Funktion und ihr Aufruf. Ordne den
# folgenden Fachbegriffen die passende Zeile zu, indem du sie als
# Kommentar dahinter schreibst: Kopf, Rumpf, Parameter, Argument,
# Aufruf, Rückgabewert
#
# def kreis_flaeche(radius):        # Zeile 1
#     flaeche = 3.1415 * radius**2  # Zeile 2
#     return flaeche                # Zeile 3
#
# ergebnis = kreis_flaeche(4)       # Zeile 4
# ```
# Ergänze die Kommentare direkt in der Code-Zelle unten (es muss nichts ausgeführt werden können, es geht nur um die Zuordnung).

# %%
def kreis_flaeche(radius):        # Zeile 1 -
    flaeche = 3.1415 * radius**2  # Zeile 2 -
    return flaeche                # Zeile 3 -

ergebnis = kreis_flaeche(4)       # Zeile 4 -

# %% [markdown]
# #### Aufgabe A15
# ```
# Schreibe eine Funktion ist_teilbar(zahl, teiler), die einen Wahrheitswert
# zurückgibt, je nachdem ob zahl ohne Rest durch teiler teilbar ist.
# Teste sie mit ist_teilbar(12, 3) und ist_teilbar(7, 2) und gib
# beide Ergebnisse aus.
# ```
# **Erwartete Ausgabe:**
# ```
# True
# False
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A16
# ```
# Schreibe eine Funktion minimum(a, b, c), die von drei übergebenen Zahlen
# die kleinste zurückgibt, ohne die eingebaute Funktion min() zu verwenden.
# Teste sie mit minimum(9, 3, 7) und minimum(-2, -8, -5) und gib
# beide Ergebnisse aus.
# ```
# **Erwartete Ausgabe:**
# ```
# 3
# -8
# ```

# %%
# your code

# %% [markdown]
# #### Aufgabe A17
# ```
# Erstelle zunächst die Datei input3.txt mit folgendem Inhalt (führe dazu
# die nächste Zelle aus):
# Rucksack
# 40
#
# Schreibe dann ein Programm, das die Datei öffnet, in der ersten Zeile
# den Namen (ohne Zeilenvorschub) in die Variable artikel und in der
# zweiten Zeile den Preis als Ganzzahl in die Variable preis einliest.
# Schließe die Datei anschließend und gib beide Variablen aus.
# ```
# **Erwartete Ausgabe:**
# ```
# Rucksack
# 40
# ```

# %%
# %%writefile input3.txt
# Rucksack
# 40

# %%
# your code

# %% [markdown]
# #### Aufgabe A18
# ```
# Erstelle zunächst die Datei input4.txt mit folgendem Inhalt (führe dazu
# die nächste Zelle aus):
# Schöne Grüße nach Köln
#
# Schreibe dann ein Programm, das die Datei mit dem passenden Parameter
# öffnet, damit die Umlaute korrekt gelesen werden, die Zeile einliest,
# den Zeilenvorschub entfernt und den Inhalt ausgibt.
# ```
# **Erwartete Ausgabe:**
# ```
# Schöne Grüße nach Köln
# ```

# %%
# %%writefile input4.txt
# Schöne Grüße nach Köln

# %%
# your code

# %% [markdown]
# #### Aufgabe A19
# ```
# Lege die Variablen name = "Paul" und punkte = 93 an und schreibe damit
# mit print(..., file=f) den Satz "Paul hat 93 Punkte erreicht." in eine
# neue Datei ausgabe2.txt. Öffne die Datei dazu im Schreibmodus mit
# encoding='utf-8' und schließe sie am Ende.
#
# Öffne die Datei anschließend erneut zum Lesen, lies die Zeile ein
# und gib sie aus, um dein Ergebnis zu prüfen.
# ```
# **Erwartete Ausgabe:**
# ```
# Paul hat 93 Punkte erreicht.
# ```

# %%
# your code
