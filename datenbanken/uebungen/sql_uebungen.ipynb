# %% [markdown]
# # Datenbanken
# ## Aufgabe Sportverein
#
# <img src='sportverein.png' width='700'>

# %%
import sqlite3

# %% [markdown]
# [Notebook](https://github.com/ktheu/InfoKursN/blob/main/datenbanken/uebungen/tabellen_erstellen.ipynb) zum Erstellen der Tabellen.

# %% [markdown]
# Erstelle passende SQL-Abfragen. Passe das Format der Ausgabe jeweils an die erwartete Ausgabe an.

# %% [markdown]
# #### Aufgabe A1
# Wieviele Trainingsorte gibt es ?
#
# ##### Erwartete Ausgabe:
# Es gibt 8 Trainingsorte.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A2
# Welche Sportarten werden angeboten (in alphabetischer Reihenfolge)?
#
# ##### Erwartete Ausgabe:
#
#     Es werden folgende Sportarten angeboten:
#     Basketball
#     Fußball
#     Langlauf
#     Schwimmen
#     Tauchen
#     Tennis
#     Turnen
#     Volleyball
#     Wasserball

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# #### Aufgabe A3
# Ändere die Sportart Fußball in Fussball. Kontrolliere die Änderung mit der Abfrage aus A2.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

con.commit()              # <---- commit brauchen wir, weil die Datenbank geändert wird!
con.close()

# %% [markdown]
# ----
# #### Aufgabe A4
#
# Wieviele Mitglieder hat der Sportverein?
#
# ##### Erwartete Ausgabe:
#
# Der Sportverein hat 930 Mitglieder.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# -----
# #### Aufgabe A5
#
# Gib die zehn häufigsten Vornamen der Mitglieder nach Häufigkeit absteigend geordnet aus.
#
# ##### Erwartete Ausgabe:
#
#     Werner     - 313
#     Wolfgang   -  18
#     Klaus      -  17
#     Peter      -  16
#     Carsten    -  16
#     Heinz      -  15
#     Bernd      -  15
#     Ulrich     -  14
#     Hans       -  14
#     Michael    -  12

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ----
#
# #### Aufgabe A6
#
# Wieviele Mitglieder haben ein Konto bei welcher Bank?
#
# ##### Erwartete Ausgabe:
#
#     181 Deutsche Bank Soest
#     166 Sparkasse Echthausen
#     201 Sparkasse Rhynern
#     186 Volksbank Mawicke
#     196 Volksbank Unna

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# -----
# #### Aufgabe A7
#
# Wieviele Fussballer haben ein Konto bei der Sparkasse Rhynern?
#
# ##### Erwartete Ausgabe:
#
#     106 Fussballer haben ein Konto bei der Sparkasse Rhynern.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A8
#
# Wie hoch ist die Summe der Mitgliedsbeiträge?
#
# ##### Erwartete Ausgabe:
#
# Die Summe aller Mitgliedsbeiträge beträgt 31730 €.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A9
#
# Welche Sportart(en) übt Mitglied Zwick aus?
#
# ##### Erwartete Ausgabe:
#
#     Mitglied Zwick übt folgende Sportarten aus:
#     Schwimmen
#     Langlauf

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A10
#
# Für welche Sportart ist Mitglied Zwick Übungsgruppenleiter?
#
# ##### Erwartete Ausgabe:
#
#     Mitglied Zwick ist Übungsgruppenleiter für die Sportart Langlauf.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A11
#
# Wieviele Mitglieder üben pro Woche in Bad1?
#
# ##### Erwartete Ausgabe:
#
# 94 Mitglieder üben pro Woche in Bad1.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A12
#
# Ordne die Sportarten nach Beliebtheit. Gib dabei die Teilnehmerzahl an.
#
# ##### Erwartete Ausgabe:
#
#     Fußball 442
#     Volleyball 318
#     Schwimmen 297
#     Wasserball 107
#     Basketball 107
#     Tennis 106
#     Tauchen 98
#     Langlauf 86
#     Turnen 84

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A13
#
# Wie hoch ist der durchschnittliche Mitgliedsbeitrag?
#
# ##### Erwartete Ausgabe:
# Der durchschnittliche Mitgliedsbeitrag beträgt 34.12 €.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()

# %% [markdown]
# ------
# #### Aufgabe A14
#
# Wieviele Mitglieder betreuen die verschiedenen Hausmeister? Genauer: Für jeden Hausmeister (in alphabetischer Reihenfolge) ist gesucht die Summe der Übungsgruppengrößen in
# den von ihm betreuten Orten.
#
# ##### Erwartete Ausgabe:
#
#
#     Hausmeister Kacmarek betreut 782 Mitglieder.
#     Hausmeister Koschulte betreut 1260 Mitglieder.
#     Hausmeister Krause betreut 306 Mitglieder.

# %%
con = sqlite3.connect("sportverein.db")
cur = con.cursor()

cur.execute("""
    ......
""")

for datensatz in cur.fetchall():
    print(datensatz)
con.close()
