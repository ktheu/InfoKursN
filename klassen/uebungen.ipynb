# %% [markdown]
# ### Übungen zu Klassen

# %%
''' Person
Erstelle eine Klasse Person 
- Attribute: name, alter
- Methoden: vorstellen

Beispiel:

p1 = Person("Anna", 15)
print(p1.vorstellen())

Erwartete Ausgabe:
Hallo, ich heiße Anna und bin 15 Jahre alt.
'''
# your code

# %%
''' Kontostand
Erstelle eine Klasse Konto  
- Attribute: inhaber, stand
- Methoden: einzahlen, abheben

Beispiel:

k = Konto("Mia", 100)
k.einzahlen(50)
print(k)
k.abheben(70)
print(k)
k.abheben(100)
print(k)

Erwartete Ausgabe:
Kontostand: 150
Kontostand: 80
Nicht genug Geld!
Kontostand: 80
'''
# your code

# %%
''' Schueler
Erstelle eine Klasse Schueler  
- Attribute: name, klasse, noten
- Methoden: durchschnitt

Beispiel:
s = Schueler("Emma", "7A", [1, 2, 3, 2])
print(s)
print(s.durchschnitt())

Erwartete Ausgabe: 

Emma geht in die Klasse 7A.
2.0
'''
# your code

# %%
''' Handy
Erstelle eine Klasse Handy
- Attribute: besitzer, akku
- Methoden: telefonieren, laden

Beispiel:

h = Handy("Ben", 50)
print(h)
h.telefonieren(10)
print(h)
h.telefonieren(50)
print(h)
h.laden()
print(h)

Erwartete Ausgabe:
Das Handy von Ben ist zu 50% geladen.
Das Handy von Ben ist zu 40% geladen.
Nicht genug Akku!
Das Handy von Ben ist zu 40% geladen.
Das Handy von Ben ist zu 100% geladen.
'''
# your code

# %%
''' Flasche
Erstelle eine Klasse Flasche 
- Attribute: volumen, inhalt
- Methoden: fuellen, trinken

Beispieldialog:

f = Flasche(500)
print(f)
f.fuellen(400)
print(f)
f.trinken(200)
print(f)
f.trinken(300)
print(f)

Erwartete Ausgabe:
Flasche: 0 / 500 ml
Flasche: 400 / 500 ml
Flasche: 200 / 500 ml
Noch 100 ml Durst!
Flasche: 0 / 500 ml
'''
# your code

# %%
''' Auto
Erstelle eine Klasse Auto
- Attribute: marke, tank, verbrauch, kilometerstand
- Methoden: kannFahren, fahre, tanke

Die Methode kannFahren prüft, ob der Tank für die übergebenen km reicht.

Beispieldialog:

opel = Auto('Opel',30, 6.2)
print(opel)
opel.fahre(50)
print(opel)
opel.fahre(400)
print(opel)
print(opel.kannFahren(30))
print(opel.kannFahren(40))
opel.fahre(40)
print(opel)
opel.tanken(40)
print(opel)

Erwartete Ausgabe:

Auto: Opel, Tank: 30.0 Liter, Kilometerstand: 0 km.
Auto: Opel, Tank: 26.9 Liter, Kilometerstand: 50 km.
Auto: Opel, Tank: 2.1 Liter, Kilometerstand: 450 km.
True
False
Nicht genug Sprit im Tank.
Auto: Opel, Tank: 2.1 Liter, Kilometerstand: 450 km.
Auto: Opel, Tank: 42.1 Liter, Kilometerstand: 450 km.
'''
# your code

# %%
''' Fach
Erstelle eine Klasse Fach
- Attribute: name, noten
- Methoden: note_hinzufuegen, durchschnitt, beste_note

Beispiel:

m = Fach("Mathematik")
print(m)
m.note_hinzufuegen(2)
m.note_hinzufuegen(3)
print(m)
m.note_hinzufuegen(1)
print(m)
print(m.beste_note())

Erwartete Ausgabe:

Mathematik, Noten: [], Durchschnitt: -
Mathematik, Noten: [2, 3], Durchschnitt: 2.5
Mathematik, Noten: [2, 3, 1], Durchschnitt: 2.0
1
'''
# your code

# %% [markdown]
# #### Vererbung

# %%
'''
Erstelle die Klasse Tier  
- Attribute: name, alter  

Erstelle die Unterklasse Hund  
- Methode: laut() 

Erstelle die Unterklasse Katze  
- Methode: laut() 

Beispiel:

h = Hund("Bello", 5)
k = Katze("Minka", 3)
print(h)
print(h.laut())
print(k)
print(k.laut())

Erwartete Ausgabe:

Bello (5 Jahre)
Wuff!
Minka (3 Jahre)
Miau!
'''
# your code

# %%
'''
Erstelle die Klasse Fahrzeug  
- Attribute: marke, geschwindigkeit  

Erstelle die Unterklasse Auto  
- zusätzliches Attribut: tank  
- Methoden: beschleunigen (geschwindigkeit erhöht sich um 15, tank erniedrigt sich um 2)

Erstelle die Unterklasse Fahrrad  
- zusätzliches Attribut: gang  
- Methoden: beschleunigen (geschwindigkeit erhöht sich um 5, gang erhöht sich um 1) 

Beispiel:

a = Auto("VW",50)
print(a)
a.beschleunigen()
print(a)
a.beschleunigen()
print(a)
f = Fahrrad("Cube")
print(f)
f.beschleunigen()
print(f)
f.beschleunigen()
print(f)

Erwartete Ausgabe:

Auto: VW, Geschwindigkeit: 0, Tank: 50
Auto: VW, Geschwindigkeit: 15, Tank: 48
Auto: VW, Geschwindigkeit: 30, Tank: 46
Fahrrad: Cube, Geschwindigkeit: 0, Gang: 1
Fahrrad: Cube, Geschwindigkeit: 5, Gang: 2
Fahrrad: Cube, Geschwindigkeit: 10, Gang: 3
'''
# your code

# %%
'''
Erstelle die Klasse Buch  
- Attribute: titel, autor, jahr  

Erstelle die Unterklasse Schulbuch  
- Attribut: fach  

Beispiel:

b = Buch("Der Hobbit", "Tolkien", 1937)
s = Schulbuch("Algebra", "Müller", 2020, "Mathematik")
print(b)
print(s)

Erwartete Ausgabe:

Der Hobbit von Tolkien (1937)
Fach: Mathematik, Algebra von Müller (2020)
'''
# your code

# %%
'''
Erstelle die Klasse Gebaeude  
- Attribute: adresse

Erstelle die Unterklasse Wohnhaus  
- Attribut: bewohner  
- Methode: einziehen 

Erstelle die Unterklasse Schule  
- Attribut: schuelerzahl  
- Methode: einschulen 

Beispiel:

w = Wohnhaus("Musterstraße 5")
print(w)
w.einziehen("Anna")
w.einziehen("Lukas")
print(w)

s = Schule("Schulweg 2", 300)
print(s)
s.einschulen(25)
print(s)

Erwartete Ausgabe:

Wohnhaus, Adresse: Musterstraße 5, Bewohner: []
Wohnhaus, Adresse: Musterstraße 5, Bewohner: ['Anna', 'Lukas']
Schule, Adresse: Schulweg 2, Schülerzahl: 300
Schule, Adresse: Schulweg 2, Schülerzahl: 325
'''
# your code
