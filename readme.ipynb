# %% [markdown]
# ### Infokurs
#
# -----
#
# [Codierung negativer Zahlen](./zweierkomplement/zweierkomplement.ipynb)
#
# [Huffman-Algorithmus](./huffman/huffman.ipynb)
#
# -----
#
# [Datenbanken](./datenbanken/datenbanken.ipynb)
#
# ------
#
# [Kryptologie](./Kryptologie/
