# %% [markdown]
# ### Sort in Python - Übungen

# %%
''' A1
Sortiere die Liste aufsteigend in-place und gib sie aus.

Erwartete Ausgabe:
[1, 2, 5, 7, 9]
'''
zahlen = [5, 2, 9, 1, 7]
# your code

# %%
''' A2
Sortiere die Liste absteigend in-place und gib sie aus.

Erwartete Ausgabe:
[9, 7, 5, 2, 1]
'''
zahlen = [5, 2, 9, 1, 7]
# your code

# %%
''' A3
Erzeuge aus der Liste eine neue Liste, die aufsteigend sortiert ist und gib sie zusammen mit der Originalliste aus. 

Erwartete Ausgabe:
[5, 2, 9, 1, 7]
[1, 2, 5, 7, 9]
'''
zahlen = [5, 2, 9, 1, 7]
# your code

# %%
''' A4
Erzeuge aus der Liste eine neue Liste, die absteigend sortiert ist und gib sie zusammen mit der Originalliste aus. 

Erwartete Ausgabe:
[5, 2, 9, 1, 7]
[9, 7, 5, 2, 1]
'''
zahlen = [5, 2, 9, 1, 7]
# your code

# %%
''' A5
Erzeuge aus der Liste zwei Listen: eine alphabetisch aufwärts und eine alphabetisch abwärts sortierte Liste und gib beide
Listen aus.

Erwartete Ausgabe: 
['Apfel', 'Banane', 'Birne', 'Orange', 'Zitrone']
['Zitrone', 'Orange', 'Birne', 'Banane', 'Apfel']
'''

woerter = ["Banane", "Apfel", "Zitrone", "Orange", "Birne"]
# your code

# %%
''' A6
Sortiere die Liste nach der Länge der Wörter

Erwartete Ausgabe:
['Hund', 'Maus', 'Katze', 'Elefant']
'''
woerter = ["Hund", "Elefant", "Katze", "Maus"]
# your code

# %%
''' A7
Sortiere die Liste nach dem 2. Element des Tupels

Erwartete Ausgabe:
[(3, 1), (4, 2), (1, 3), (2, 5)]
'''
paare = [(1, 3), (4, 2), (2, 5), (3, 1)]
# your code

# %%
''' A8
Sortiere die Liste nach dem letzten Buchstaben

Erwartete Ausgabe:
['Katze', 'Ball', 'Auto', 'Haus']
'''
woerter = ["Auto", "Haus", "Ball", "Katze"]
# your code

# %%
''' A9
Sortiere die Liste nach dem Vornamen
Hinweis: nutze die Methode split()

Erwartete Ausgabe:
['Müller, Anna', 'Schmidt, Ben', 'Fischer, Carla', 'Becker, Daniel']
'''
namen = ['Müller, Anna', 'Becker, Daniel', 'Schmidt, Ben', 'Fischer, Carla']

# %%
''' A10
Sortiere die Namen alphabetisch, ignoriere Groß-/Kleinschreibung

Erwartete Ausgabe:
['anna', 'Ben', 'carla', 'Daniel']
'''
namen = ["Ben", "anna", "Daniel", "carla"]
# your code

# %%
''' A11
Sortiere die Wörter nach der Anzahl der Vokale (Umlaute zählen auch als Vokale).

Erwartete Ausgabe:
['Python', 'Haus', 'Elefant', 'Autofahrt', 'Universität']
'''
woerter = ["Haus", "Autofahrt", "Universität", "Python", "Elefant"]
# your code

# %%
''' A12
Sortiere die schuelerdaten nach den Noten und bei gleichen Noten alphabetisch.

Erwartete Ausgabe:
[{'name': 'Daniel', 'note': 1}, {'name': 'Anna', 'note': 2}, {'name': 'Carla', 'note': 2}, {'name': 'Ben', 'note': 3}]
'''
schueler = [
    {"name": "Carla", "note": 2},
    {"name": "Anna", "note": 2},
    {"name": "Ben", "note": 3},  
    {"name": "Daniel", "note": 1}
]

# %%
''' A13
Sortiere die Filmdaten nach Bewertung (absteigend) und Jahr (aufsteigend).

Erwartete Ausgabe:

[{'titel': 'Inception', 'jahr': 2010, 'bewertung': 8.8},
 {'titel': 'Matrix', 'jahr': 1999, 'bewertung': 8.7},
 {'titel': 'Python Connection', 'jahr': 2006, 'bewertung': 8.6},
 {'titel': 'Interstellar', 'jahr': 2014, 'bewertung': 8.6},
 {'titel': 'The Prestige', 'jahr': 2006, 'bewertung': 8.5}]
 
'''
filme = [
    {"titel": "Inception", "jahr": 2010, "bewertung": 8.8},
    {"titel": "Matrix", "jahr": 1999, "bewertung": 8.7},
    {"titel": "Interstellar", "jahr": 2014, "bewertung": 8.6},
    {"titel": "Python Connection", "jahr": 2006, "bewertung": 8.6},
    {"titel": "The Prestige", "jahr": 2006, "bewertung": 8.5}
]
# your code

# %%
''' A14
Sortiere die tage in der richtigen Reihenfolge

Erwartete Ausgabe:
['Montag', 'Dienstag', 'Donnerstag', 'Samstag', 'Sonntag']
'''
tage = ["Dienstag", "Donnerstag", "Montag", "Sonntag", "Samstag"]
reihenfolge = {
    "Montag": 0, "Dienstag": 1, "Mittwoch": 2, "Donnerstag": 3,
    "Freitag": 4, "Samstag": 5, "Sonntag": 6
}
# your code

# %% [markdown]
# #### Codingame
#
# - [Add them up](https://www.codingame.com/training/easy/addem-up)
