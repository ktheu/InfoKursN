# %% [markdown]
# ### Kryptologie
#
# Die **Kryptologie** ist die Wissenschaft von der sicheren Übermittlung (auch Speicherung) von Information (Daten).
# Üblich ist eine Unterteilung in **Kryptographie** (wie erstellt man eine Chiffre, d.h. ein Verschlüsselungssystem) und in **Kryptoanalyse** (wie knackt man eine Chiffre).

# %% [markdown]
# #### Sicherheitsziele
#
# * **Vertraulichkeit**: Die Nachricht, die man erhält, ist nicht von dritten Personen gelesen worden.
# * **Integrität**: Die Nachricht, die man erhält, ist von keiner dritten Person manipuliert worden.
# * **Authentizität**: Die Nachricht, die man erhält, stammt wirklich von der Person, die als Absender angegeben ist.
# * **Verbindlichkeit**: Der Urheber kann nachträglich nicht bestreiten, die Nachricht verfasst zu haben.

# %% [markdown]
# #### Ausgangssituation und Rollen
# **Alice** will **Bob** eine Nachricht schicken. Dazu wandelt sie den **Klartext** in einen **Geheimtext** um (**Chiffrierung**) und verschickt den Geheimtext. Bob wandelt den Geheimtext wieder in einen Klartext um (**Dechiffrierung**).
#
# **Angreifer**: **Eve** will den Text mitlesen (ohne ihn zu verändern). **Mallory** will die verschickte Nachricht verändern.

# %% [markdown]
# #### Transposition
#
# Bei Transpositionsverfahren werden die Buchstaben des Klartexts nicht verändert, sondern nur anders angeordnet.
#
# Beispiel: Die **Skytale** ist ein altes Verschlüsselungsverfahren, Sender und Empfänger besaßen jeweils eine Skytale, einen Zylinder mit identischem Umfang. Der Sender wickelte ein schmales Pergamentband spiralförmig um seinen Zylinder und schrieb die Nachricht längs auf das Band. Nach dem Abwickeln war der Text unlesbar. Der Umfang der Skytale ist der Schlüssel für diese Chiffre. Erst auf einer Skytale mit demselben Umfang konnte die Nachricht wieder gelesen werden.
#
# <img src='./bild1.png' width='401'>

# %% [markdown]
# #### Monoalphabetische Substitution
#
#
# Die **Cäsar-Chiffre** gehört zu den **monoalphabetischem Substitutionschiffren**: Jeder Klartextbuchstabe wird durch immer denselben Geheimtextbuchstaben ersetzt. Bei der Cäsar-Chiffre geschieht die Ersetzung durch Verschiebung im Alphabet um einen festen Betrag.
#
#
#
# [Cäsar-Chiffre](https://kryptografie.de/kryptografie/chiffre/caesar.htm)
#
# Für die Cäsar-Chiffre gibt es nur 25 verschiedene Schlüssel. Der **key-space** hat die Größe 25. Mit einem **brute-force-Angriff** lässt sich eine Cäsar-Chiffre brechen.
#
# Bei einer beliebigen monoalphabetischen Substitution
# wird ein Buchstabe durch einen anderen ersetzt. Es muss nicht mehr eine feste Verschiebung sein (wie bei Cäsar), sondern kann eine beliebige Permutation sein. Der Schlüssel ist diese Permutation.

# %%
import random
s = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
a = list(s)
random.shuffle(a)
s1 = ''.join(a)
print(s)
print(s1)
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# GVBHYMPKAELFZQWUXODITSNCRJ

# %% [markdown]
# Der *key-space* besteht aus allen Permutationen der 26 Buchstaben. Ein brute-force Angriff ist nicht mehr möglich.

# %%
import math
a = math.factorial(26)
print(f'{a}, {a:5.2e}')
# Out:
# 403291461126605635584000000, 4.03e+26

# %% [markdown]
# Mit einer **Häufigkeitsanalyse** lassen sich monoalphabetische Substitutionen brechen. Man vergleicht die Häufigkeit der im Geheimtext vorkommenden Zeichen mit der normalen Häufigkeit von Buchstaben in deutschen Texten. Mit etwas Ausprobieren erkennt man, welche Permutation benutzt wurde.

# %% [markdown]
#
#     NUI NUKUMXBUQUIGZDK JXM VUIBI CIGIUFJI ZDQIGIQ XBBMXKQ VIGXIDNIGM UDTAGPXMUADID LAIDDID JIZMI UDDIGJXBC WIDUKIG QILZDNID WIBMWIUM ZICIGMGXKID WIGNID NXCIU QHUIBID FAPHZMIG DIMYWIGLI ZDN NXQ UDMIGDIM IUDI WUFJMUKI GABBI KBIUFJYIUMUK KIWUDDM NIG QFJZMY HIGQAIDBUFJIG NXMID UPPIG PIJG XD CINIZMZDK QUFJIGI HXQQWAIGMIG VIGQFJBZIQQIBZDKQVIGTXJGID ZDN IUD CIWZQQMIG ZPKXDK PUM NUKUMXBID PINUID JIBTID NXCIU NUI HGUVXMQHJXIGI YZ QFJZIMYID ZDN GUQULID UP UDMIGDIM YZ VIGGUDKIGD

# %% [markdown]
# <img src='./haeufigkeit.png' width='500'>

# %% [markdown]
# Übung: Entziffere den Geheimtext mit dem [Solver-Tool](https://kryptografie.de/kryptografie/kryptoanalyse/solver-tool-zum-manuellen-knacken-von-monoalphabetischen-substitutions-chiffren.htm)

# %% [markdown]
# #### Polyalphabetische Substitution
#
# Die **Vigenere-Chiffre** gehört zu den polyalphabetischen Substitutionschiffren. Derselbe Klartextbuchstabe kann durch unterschiedliche Geheimtextbuchstaben ersetzt werden. Es kommt auf seine Position im Text an.
# Sender und Empfänger vereinbaren ein Schlüsselwort. Oft schreibt man es mit Wiederholungen unter den Klartext. Der Schlüsselbuchstabe bestimmt dann, mit welchem Alphabet der Klartextbuchstabe verschlüsselt wird.
#
# <img src='./vigenere.png' width='500'>
#
# [Vigenere](https://kryptografie.de/kryptografie/chiffre/vigenere.htm)

# %% [markdown]
# Die Vigenere-Chiffre wurde um 1500 entwickelt und galt ca. 350 Jahre als sicher. Das Hauptproblem beim Brechen der Chiffre ist die Bestimmung der Schlüssellänge. Ist die Schüssellänge beispielsweise 5, dann ist jedes 5.Zeichen um denselben Betrag verschoben. Die Verschiebung lässt sich mit einer Häufigkeitsanalyse bestimmen.
#
# Ein Verfahren zur Bestimmung der Schlüssellänge ist der **Kasiski-Test**. Wenn häufig vorkommende Buchstabenfolgen zufällig auf dieselbe Schlüsselposition fallen, wiederholen sich auch gleichartige Sequenzen im Geheimtext. Der Abstand dieser Sequenzen ist also ein Vielfaches der Schlüssellänge.

# %% [markdown]
# <img src='./kasiski.png' width='450'>
#
# [Kasiski-Test](https://kryptografie.de/kryptografie/kryptoanalyse/kasiski-test.htm)

# %% [markdown]
# #### One Time Pad
#
# Das One Time Pad können wir uns vorstellen wie eine Vigenere-Chiffre, bei dem der Schlüssel genauso lang ist wie die zu verschlüsselnde Nachricht und bei der die Buchstabenreihenfolge des Schlüssels zufällig ist. Das One Time Pad ist absolut sicher, denn bei unbekanntem Schlüssel ist zu einem gegebenen Geheimtext jeder Klartext gleich wahrscheinlich.
#
# Das One Time Pad ist aber auch äußerst unpraktisch, denn der unter Umständen sehr lange Schlüssel muss ja irgendwie zwischen den Kommunikationspartnern ausgetauscht werden - er lässt sich wegen der Zufälligkeit der Buchstabenfolge in der Regel auch nicht "auswendig lernen".

# %% [markdown]
# #### Kerckhoffs' Prinzip
#
# Ein konkretes Verschlüsselungsverfahren besteht aus dem Verschlüsselungsalgorithmus und einem Schlüssel, z.B. Cäsar-Chiffre mit Schlüssel 3.
#
# Das Kerckhoffs’sche Prinzip ist ein im Jahr 1883 von Auguste Kerckhoffs formulierter Grundsatz der modernen Kryptographie, welcher besagt, dass die Sicherheit eines Verschlüsselungsverfahrens auf der Geheimhaltung des Schlüssels beruht und nicht auf der Geheimhaltung des Verschlüsselungsalgorithmus.

# %% [markdown]
# #### Asymmetrische Verschlüsselung
#
# Bei der asymmetrischen Verschlüsselung besitzt jede Person ein **Schlüsselpaar**:
#
# - **Öffentlicher Schlüssel (Public Key):** darf bekannt gemacht/veröffentlicht werden. Mit ihm können Nachrichten **verschlüsselt** werden.
# - **Privater Schlüssel (Private Key):** bleibt geheim. Nur mit ihm können die verschlüsselten Nachrichten wieder **entschlüsselt** werden.
#
# **Ablauf, wenn Alice Bob eine Nachricht schickt:**
# 1. Alice verschlüsselt die Nachricht mit **Bobs öffentlichem** Schlüssel.
# 2. Bob entschlüsselt die Nachricht mit **seinem privaten** Schlüssel.
# 3. Eine dritte Person kann die Nachricht trotz Kenntnis des öffentlichen Schlüssels nicht lesen, da zum Entschlüsseln der **private** Schlüssel nötig ist — und der lässt sich aus dem öffentlichen Schlüssel praktisch nicht berechnen.
#
# **Vorteil gegenüber symmetrischer Verschlüsselung:** Bei symmetrischer Verschlüsselung müssen Sender und Empfänger vorab denselben geheimen Schlüssel sicher austauschen. Bei asymmetrischer Verschlüsselung entfällt dieser Austausch, da der öffentliche Schlüssel offen übertragen werden darf.
#
# **Hybride Verschlüsselung (Praxis):** Da asymmetrische Verfahren rechenaufwendig und langsam sind, wird meist eine Kombination genutzt:
# Der eigentliche Klartext wird mit einem schnellen **symmetrischen** Verfahren verschlüsselt; nur der kurze symmetrische Schlüssel wird asymmetrisch ausgetauscht. Wenn Alice und Bob beide private und öffentliche Schlüssel haben, können Sie mit dem Diffie-Hellman Verfahren einen symmetrischen Schlüssel vereinbaren, ohne dass ein Angreifer, der die gesamte Kommunikation mitliest, diesen Schlüssel ermitteln kann.

# %% [markdown]
# #### Verschlüsselung im Alltag
#
# Verschlüsselung wird eingesetzt, um Daten vor unbefugtem Zugriff zu schützen. Ein wichtiger Anwendungsbereich ist die verschlüsselte Speicherung von Daten auf Computern, Smartphones oder USB-Sticks. Selbst wenn ein Gerät verloren geht, können die Daten ohne den richtigen Schlüssel nicht gelesen werden.
#
# Auch bei der Übertragung von Daten im Internet spielt Verschlüsselung eine große Rolle. Webseiten mit HTTPS verschlüsseln die Verbindung zwischen Browser und Server, sodass Passwörter oder andere persönliche Informationen nicht einfach mitgelesen werden können. Ebenso verwenden viele Messenger-Dienste eine Ende-zu-Ende-Verschlüsselung, damit nur die beteiligten Personen die Nachrichten lesen können.

# %% [markdown]
# #### Cookies
# Cookies sind kleine Dateien, die eine Webseite im Browser speichert und bei einem erneuten Besuch wieder ausliest. Damit lassen sich u. a. Login-Zustände, Spracheinstellungen, der Warenkorb, besuchte Seiten und eine eindeutige Nutzer-ID speichern. In Kombination entstehen daraus **Nutzungsprofile** (Interessen, Surfverhalten), die z. B. für personalisierte Werbung genutzt werden.
#
# - **Notwendige Cookies:** für die Grundfunktion der Seite erforderlich (z. B. Login-Sitzung, Warenkorb).
# - **Tracking-Cookies:** verfolgen das Verhalten über mehrere Webseiten hinweg, meist von Drittanbietern (Werbenetzwerke), zu Werbe- oder Analysezwecken.
#
# #### Geodaten
# Smartphones bestimmen ihren Standort über GPS (Satellitensignale), ersatzweise über nahe WLAN-Netze oder die Entfernung zu Mobilfunkmasten. Über die Zeit gesammelte Standortdaten ergeben ein **Bewegungsprofil**, aus dem sich Wohnort, Arbeitsplatz, Tagesablauf oder regelmäßig besuchte Orte ableiten lassen.

# %% [markdown]
# #### Möglichkeiten zum Schutz personenbezogener Daten
#
# Es gibt verschiedene Möglichkeiten, das Sammeln personenbezogener Daten einzuschränken. Viele Browser bieten einen anonymen Modus oder ermöglichen das Blockieren von Tracking-Cookies. Dadurch können Webseiten Nutzer schlechter verfolgen.
#
# Außerdem sollte man die Berechtigungen von Apps regelmäßig überprüfen. Viele Apps verlangen Zugriff auf Kamera, Mikrofon oder Kontakte, obwohl dies nicht immer notwendig ist. Solche Rechte sollten nur erteilt werden, wenn sie wirklich gebraucht werden.
#
# Auch die Standortfreigabe sollte bewusst genutzt werden. Wenn der Standort nicht benötigt wird, kann die Freigabe deaktiviert werden. Dadurch werden weniger Bewegungsdaten gesammelt und gespeichert.
